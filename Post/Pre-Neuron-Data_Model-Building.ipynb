# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilfaizal01/NeuroInformatics-Project/blob/main/Post/Pre-Neuron-Data_Model-Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

# %%
C_df = pd.read_csv('/content/cn-C-array.csv',header=None)
C_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.001439  0.005755  0.026316  0.004065  0.014925  0.009174  0.000000
# 1  0.000000  0.000000  0.973684  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.014925  0.205128
#
#          7         8         9   ...   29   30   31        32        33  \
# 0  0.241935  0.913669  0.900719  ...  0.0  0.0  0.0  0.477698  0.001439
# 1  0.000000  0.081769  0.956349  ...  0.0  0.0  0.0  0.953083  0.009383
# 2  0.000000  0.184211  0.973684  ...  0.0  0.0  0.0  0.157895  0.473684
# 3  0.000000  0.000000  0.000000  ...  0.0  0.0  0.0  0.004065  0.000000
# 4  0.016129  0.014925  0.000000  ...  0.0  0.0  0.0  0.000000  0.000000
#
#          34        35        36        37        38
# 0  0.001439  0.002878  0.006878  0.002825  0.000000
# 1  0.628922  0.001340  0.930295  0.000000  0.001773
# 2  0.000000  0.973684  0.210526  0.552632  0.000000
# 3  0.000000  0.000000  0.646341  0.000000  0.000000
# 4  0.014925  0.000000  0.000000  0.000000  0.000000
#
# [5 rows x 39 columns]

# %%
G_df = pd.read_csv('/content/RNA_mean_part.csv')
G_df.head()
# Out:
#          Unnamed: 0        C2        C3       Dm1      Dm10      Dm11  \
# 0              Nep3  0.135671  0.178622  0.476190  0.205489  0.273713
# 1  tRNA:Pro-CGG-1-1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2            CG9570  0.000000  0.000000  0.007937  0.000000  0.000000
# 3             Or19b  0.000000  0.000000  0.000000  0.000000  0.000000
# 4           CG15322  0.025534  0.020241  0.023810  0.024766  0.018970
#
#        Dm12       Dm4       Dm9        L1  ...       T5b       T5c       T5d  \
# 0  0.397906  0.283333  0.259843  0.146947  ...  0.098475  0.098007  0.082068
# 1  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2  0.001745  0.000000  0.000000  0.000421  ...  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4  0.024433  0.008333  0.041995  0.027789  ...  0.022222  0.022425  0.024194
#
#         Tm1       Tm2      Tm20       Tm3       Tm4      TmY3     TmY5a
# 0  0.152154  0.121829  0.160268  0.122828  0.170845  0.167037  0.193115
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000344
# 3  0.000898  0.000000  0.000000  0.000300  0.000000  0.000000  0.000000
# 4  0.018402  0.019600  0.016203  0.025464  0.023139  0.020533  0.023752
#
# [5 rows x 40 columns]

# %%
G_data = G_df.iloc[:,1:].values
G_data[:,0]
# Out:
# array([0.13567073, 0.        , 0.        , ..., 0.0003811 , 0.        ,
#        0.01410061])

# %%
tags = G_df.iloc[:,0].values
Gi_tags = np.core.defchararray.add('Pre_G(i)_', tags.astype(str))
Gj_tags = np.core.defchararray.add('Post_G(j)_', tags.astype(str))

# %%
C_data = {}
for i in range(len(Gi_tags)):
  C_data[Gi_tags[i]] = []
  C_data[Gj_tags[i]] = []

# %%
C_DataFrame = pd.DataFrame(C_data)
C_DataFrame.head()
# Out:
# Empty DataFrame
# Columns: [Pre_G(i)_Nep3, Post_G(j)_Nep3, Pre_G(i)_tRNA:Pro-CGG-1-1, Post_G(j)_tRNA:Pro-CGG-1-1, Pre_G(i)_CG9570, Post_G(j)_CG9570, Pre_G(i)_Or19b, Post_G(j)_Or19b, Pre_G(i)_CG15322, Post_G(j)_CG15322, Pre_G(i)_Or19a, Post_G(j)_Or19a, Pre_G(i)_karr, Post_G(j)_karr, Pre_G(i)_fd19B, Post_G(j)_fd19B, Pre_G(i)_CG17003, Post_G(j)_CG17003, Pre_G(i)_CG12655, Post_G(j)_CG12655, Pre_G(i)_CR32821, Post_G(j)_CR32821, Pre_G(i)_CG33217, Post_G(j)_CG33217, Pre_G(i)_Vps11, Post_G(j)_Vps11, Pre_G(i)_RpL10, Post_G(j)_RpL10, Pre_G(i)_G9a, Post_G(j)_G9a, Pre_G(i)_cin, Post_G(j)_cin, Pre_G(i)_CG3777, Post_G(j)_CG3777, Pre_G(i)_CG12470, Post_G(j)_CG12470, Pre_G(i)_Or1a, Post_G(j)_Or1a, Pre_G(i)_y, Post_G(j)_y, Pre_G(i)_ac, Post_G(j)_ac, Pre_G(i)_sc, Post_G(j)_sc, Pre_G(i)_l(1)sc, Post_G(j)_l(1)sc, Pre_G(i)_ase, Post_G(j)_ase, Pre_G(i)_CG13373, Post_G(j)_CG13373, Pre_G(i)_CG32817, Post_G(j)_CG32817, Pre_G(i)_CG3176, Post_G(j)_CG3176, Pre_G(i)_CG3156, Post_G(j)_CG3156, Pre_G(i)_CG17778, Post_G(j)_CG17778, Pre_G(i)_arg, Post_G(j)_arg, Pre_G(i)_CG17896, Post_G(j)_CG17896, Pre_G(i)_CG18273, Post_G(j)_CG18273, Pre_G(i)_CR18275, Post_G(j)_CR18275, Pre_G(i)_Cyp4g1, Post_G(j)_Cyp4g1, Pre_G(i)_Pgcl, Post_G(j)_Pgcl, Pre_G(i)_CG32816, Post_G(j)_CG32816, Pre_G(i)_CG13375, Post_G(j)_CG13375, Pre_G(i)_CG3038, Post_G(j)_CG3038, Pre_G(i)_Appl, Post_G(j)_Appl, Pre_G(i)_CG13369, Post_G(j)_CG13369, Pre_G(i)_CG17829, Post_G(j)_CG17829, Pre_G(i)_Mybbp1A, Post_G(j)_Mybbp1A, Pre_G(i)_su(sable), Post_G(j)_su(sable), Pre_G(i)_CG13367, Post_G(j)_CG13367, Pre_G(i)_Roc1a, Post_G(j)_Roc1a, Pre_G(i)_CG5254, Post_G(j)_CG5254, Pre_G(i)_CG5273, Post_G(j)_CG5273, Pre_G(i)_fz3, Post_G(j)_fz3, Pre_G(i)_CG16989, Post_G(j)_CG16989, Pre_G(i)_CG14635, Post_G(j)_CG14635, ...]
# Index: []
#
# [0 rows x 35122 columns]

# %%
len(list(C_data.keys()))
# Out:
# 35122

# %%
# Sample C-matrix representing cell connections
C_matrix = C_df
# Sample G-matrix representing gene expression
G_matrix = G_data

# Initialize an empty list to store the extracted features and target
rows = []

# Iterate over the A-matrix to find cell connections and extract gene expression features
for i in range(len(C_matrix)):
    for j in range(len(C_matrix[i])):
        if i != j and C_matrix[i][j] > 0.1:
            # Extract gene expression features for connected cells
            features_i = pd.Series(G_matrix[:, i])
            features_j = pd.Series(G_matrix[:, j])
            # Add the features and connection status to the list
            new_row = {'connect': 1}
            for k, (feature_i, feature_j) in enumerate(zip(features_i, features_j), start=1):
                new_row[f'Pre_G(i)_{k}'] = feature_i
                new_row[f'Post_G(j)_{k}'] = feature_j
            # Append the new row to the list
            rows.append(new_row)
        elif i != j:
            features_i = pd.Series(G_matrix[:, i])
            features_j = pd.Series(G_matrix[:, j])
            # Add the features and connection status to the list for non-connected cells
            new_row = {'connect': 0}
            for k, (feature_i, feature_j) in enumerate(zip(features_i, features_j), start=1):
                new_row[f'Pre_G(i)_{k}'] = feature_i
                new_row[f'Post_G(j)_{k}'] = feature_j
            # Append the new row to the list
            rows.append(new_row)

# Create a DataFrame from the list of dictionaries
C_DataFrame = pd.DataFrame(rows)

# Print the DataFrame
print(C_DataFrame)
# Out:
#       connect  Pre_G(i)_1  Post_G(j)_1  Pre_G(i)_2  Post_G(j)_2  Pre_G(i)_3  \
# 0           0    0.135671     0.178622         0.0          0.0    0.000000
# 1           0    0.135671     0.476190         0.0          0.0    0.000000
# 2           0    0.135671     0.205489         0.0          0.0    0.000000
# 3           0    0.135671     0.273713         0.0          0.0    0.000000
# 4           0    0.135671     0.397906         0.0          0.0    0.000000
# ...       ...         ...          ...         ...          ...         ...
# 1477        0    0.193115     0.121829         0.0          0.0    0.000344
# 1478        0    0.193115     0.160268         0.0          0.0    0.000344
# 1479        1    0.193115     0.122828         0.0          0.0    0.000344
# 1480        1    0.193115     0.170845         0.0          0.0    0.000344
# 1481        1    0.193115     0.167037         0.0          0.0    0.000344
#
#       Post_G(j)_3  Pre_G(i)_4  Post_G(j)_4  Pre_G(i)_5  ...  Pre_G(i)_17557  \
# 0        0.000000         0.0       0.0000    0.025534  ...        0.297637
# 1        0.007937         0.0       0.0000    0.025534  ...        0.297637
# 2        0.000000         0.0       0.0000    0.025534  ...        0.297637
# 3        0.000000         0.0       0.0000    0.025534  ...        0.297637
# 4        0.001745         0.0       0.0000    0.025534  ...        0.297637
# ...           ...         ...          ...         ...  ...             ...
# 1477     0.000000         0.0       0.0000    0.023752  ...        0.371773
# 1478     0.000000         0.0       0.0000    0.023752  ...        0.371773
# 1479     0.000000         0.0       0.0003    0.023752  ...        0.371773
# 1480     0.000000         0.0       0.0000    0.023752  ...        0.371773
# 1481     0.000000         0.0       0.0000    0.023752  ...        0.371773
#
#       Post_G(j)_17557  Pre_G(i)_17558  Post_G(j)_17558  Pre_G(i)_17559  \
# 0            0.318537        0.128430         0.111506        0.000381
# 1            0.523810        0.128430         0.333333        0.000381
# 2            0.393574        0.128430         0.200134        0.000381
# 3            0.417344        0.128430         0.219512        0.000381
# 4            0.500873        0.128430         0.277487        0.000381
# ...               ...             ...              ...             ...
# 1477         0.311299        0.141136         0.164489        0.000000
# 1478         0.300810        0.141136         0.107080        0.000000
# 1479         0.311564        0.141136         0.108748        0.000000
# 1480         0.349017        0.141136         0.111454        0.000000
# 1481         0.357936        0.141136         0.164262        0.000000
#
#       Post_G(j)_17559  Pre_G(i)_17560  Post_G(j)_17560  Pre_G(i)_17561  \
# 0            0.000000             0.0         0.000000        0.014101
# 1            0.000000             0.0         0.007937        0.014101
# 2            0.000000             0.0         0.000000        0.014101
# 3            0.005420             0.0         0.002710        0.014101
# 4            0.000000             0.0         0.000000        0.014101
# ...               ...             ...              ...             ...
# 1477         0.000000             0.0         0.000000        0.015835
# 1478         0.001057             0.0         0.000000        0.015835
# 1479         0.000599             0.0         0.000000        0.015835
# 1480         0.000771             0.0         0.000386        0.015835
# 1481         0.000555             0.0         0.000000        0.015835
#
#       Post_G(j)_17561
# 0            0.016690
# 1            0.007937
# 2            0.012048
# 3            0.013550
# 4            0.001745
# ...               ...
# 1477         0.014604
# 1478         0.009158
# 1479         0.011983
# 1480         0.010413
# 1481         0.018868
#
# [1482 rows x 35123 columns]

# %%
C_DataFrame.columns = ['connect'] + list(C_data.keys())

# %%
X = C_DataFrame.iloc[:,1:]
X
# Out:
#       Pre_G(i)_Nep3  Post_G(j)_Nep3  Pre_G(i)_tRNA:Pro-CGG-1-1  \
# 0          0.135671        0.178622                        0.0
# 1          0.135671        0.476190                        0.0
# 2          0.135671        0.205489                        0.0
# 3          0.135671        0.273713                        0.0
# 4          0.135671        0.397906                        0.0
# ...             ...             ...                        ...
# 1477       0.193115        0.121829                        0.0
# 1478       0.193115        0.160268                        0.0
# 1479       0.193115        0.122828                        0.0
# 1480       0.193115        0.170845                        0.0
# 1481       0.193115        0.167037                        0.0
#
#       Post_G(j)_tRNA:Pro-CGG-1-1  Pre_G(i)_CG9570  Post_G(j)_CG9570  \
# 0                            0.0         0.000000          0.000000
# 1                            0.0         0.000000          0.007937
# 2                            0.0         0.000000          0.000000
# 3                            0.0         0.000000          0.000000
# 4                            0.0         0.000000          0.001745
# ...                          ...              ...               ...
# 1477                         0.0         0.000344          0.000000
# 1478                         0.0         0.000344          0.000000
# 1479                         0.0         0.000344          0.000000
# 1480                         0.0         0.000344          0.000000
# 1481                         0.0         0.000344          0.000000
#
#       Pre_G(i)_Or19b  Post_G(j)_Or19b  Pre_G(i)_CG15322  Post_G(j)_CG15322  \
# 0                0.0           0.0000          0.025534           0.020241
# 1                0.0           0.0000          0.025534           0.023810
# 2                0.0           0.0000          0.025534           0.024766
# 3                0.0           0.0000          0.025534           0.018970
# 4                0.0           0.0000          0.025534           0.024433
# ...              ...              ...               ...                ...
# 1477             0.0           0.0000          0.023752           0.019600
# 1478             0.0           0.0000          0.023752           0.016203
# 1479             0.0           0.0003          0.023752           0.025464
# 1480             0.0           0.0000          0.023752           0.023139
# 1481             0.0           0.0000          0.023752           0.020533
#
#       ...  Pre_G(i)_dock  Post_G(j)_dock  Pre_G(i)_kraken  Post_G(j)_kraken  \
# 0     ...       0.297637        0.318537         0.128430          0.111506
# 1     ...       0.297637        0.523810         0.128430          0.333333
# 2     ...       0.297637        0.393574         0.128430          0.200134
# 3     ...       0.297637        0.417344         0.128430          0.219512
# 4     ...       0.297637        0.500873         0.128430          0.277487
# ...   ...            ...             ...              ...               ...
# 1477  ...       0.371773        0.311299         0.141136          0.164489
# 1478  ...       0.371773        0.300810         0.141136          0.107080
# 1479  ...       0.371773        0.311564         0.141136          0.108748
# 1480  ...       0.371773        0.349017         0.141136          0.111454
# 1481  ...       0.371773        0.357936         0.141136          0.164262
#
#       Pre_G(i)_CG13949  Post_G(j)_CG13949  Pre_G(i)_CG13950  \
# 0             0.000381           0.000000               0.0
# 1             0.000381           0.000000               0.0
# 2             0.000381           0.000000               0.0
# 3             0.000381           0.005420               0.0
# 4             0.000381           0.000000               0.0
# ...                ...                ...               ...
# 1477          0.000000           0.000000               0.0
# 1478          0.000000           0.001057               0.0
# 1479          0.000000           0.000599               0.0
# 1480          0.000000           0.000771               0.0
# 1481          0.000000           0.000555               0.0
#
#       Post_G(j)_CG13950  Pre_G(i)_ninaA  Post_G(j)_ninaA
# 0              0.000000        0.014101         0.016690
# 1              0.007937        0.014101         0.007937
# 2              0.000000        0.014101         0.012048
# 3              0.002710        0.014101         0.013550
# 4              0.000000        0.014101         0.001745
# ...                 ...             ...              ...
# 1477           0.000000        0.015835         0.014604
# 1478           0.000000        0.015835         0.009158
# 1479           0.000000        0.015835         0.011983
# 1480           0.000386        0.015835         0.010413
# 1481           0.000000        0.015835         0.018868
#
# [1482 rows x 35122 columns]

# %%
pre_features = [col for col in X.columns if 'Pre' in col]

# Select those columns from the dataset
preX = X[pre_features]

preX.shape
# Out:
# (1482, 17562)

# %%
post_features = [col for col in X.columns if 'Post' in col]

postX = X[post_features]

postX.shape
# Out:
# (1482, 17561)

# %%
y = C_DataFrame['connect']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1477    0
# 1478    0
# 1479    1
# 1480    1
# 1481    1
# Name: connect, Length: 1482, dtype: int64

# %% [markdown]
# # **SPLITTING THE DATASET**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train_pre, X_test_pre, y_train, y_test = train_test_split(preX, y, test_size=0.20, random_state=42)

# %%
X_train_post, X_test_post, y_train, y_test = train_test_split(postX, y, test_size=0.20, random_state=42)

# %% [markdown]
# # **PCA-30 components since half of the data is used**

# %%
from sklearn.decomposition import PCA
pca30 = PCA(n_components=30)
pretrain_features_30 = pca30.fit_transform(X_train_pre)
pretest_features_30 = pca30.transform(X_test_pre)

# %%
from sklearn.decomposition import PCA
pca30 = PCA(n_components=30)
posttrain_features_30 = pca30.fit_transform(X_train_post)
posttest_features_30 = pca30.transform(X_test_post)

# %% [markdown]
# # **Pre and Post Model Building**

# %%
from sklearn.linear_model import LogisticRegression

classifiers = {
    'Random Forest': RandomForestClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'XGBoost': xgb.XGBClassifier(),
    'SVM-Linear': svm.SVC(kernel='linear',class_weight='balanced',probability=True),
    'SVM-Poly': svm.SVC(kernel='poly',class_weight='balanced',probability=True)
}

for name, clf in classifiers.items():
    print(f"Training {name}...")
    clf.fit(pretrain_features_30, y_train)
    y_pred = clf.predict(pretest_features_30)
    train_accuracy = clf.score(pretrain_features_30, y_train)
    print(f"{name} Train Accuracy: {train_accuracy:.2f}")
    test_accuracy = accuracy_score(y_test, y_pred)
    print("Test Accuracy:", test_accuracy)
    recall = recall_score(y_test, y_pred)
    print("Test Recall:", recall)
    precision = precision_score(y_test, y_pred)
    print("Test Precision:", precision)
    f1Score = f1_score(y_test, y_pred)
    print("Test F1_Score:", f1Score)
    print()
# Out:
# Training Random Forest...
# Random Forest Train Accuracy: 0.98
# Test Accuracy: 0.7878787878787878
# Test Recall: 0.14
# Test Precision: 0.25925925925925924
# Test F1_Score: 0.18181818181818182
#
# Training Decision Tree...
# Decision Tree Train Accuracy: 0.98
# Test Accuracy: 0.7946127946127947
# Test Recall: 0.16
# Test Precision: 0.2962962962962963
# Test F1_Score: 0.20779220779220778
#
# Training Logistic Regression...
# Logistic Regression Train Accuracy: 0.86
# Test Accuracy: 0.8316498316498316
# Test Recall: 0.0
# Test Precision: 0.0
# Test F1_Score: 0.0
#
# Training Gradient Boosting...
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Gradient Boosting Train Accuracy: 0.89
# Test Accuracy: 0.8148148148148148
# Test Recall: 0.02
# Test Precision: 0.14285714285714285
# Test F1_Score: 0.03508771929824562
#
# Training XGBoost...
# XGBoost Train Accuracy: 0.90
# Test Accuracy: 0.8080808080808081
# Test Recall: 0.06
# Test Precision: 0.23076923076923078
# Test F1_Score: 0.09523809523809523
#
# Training SVM-Linear...

# %%
classifiers = {
    'Random Forest': RandomForestClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'XGBoost': xgb.XGBClassifier(),
    'SVM-Linear': svm.SVC(kernel='linear',class_weight='balanced',probability=True),
    'SVM-Poly': svm.SVC(kernel='poly',class_weight='balanced',probability=True)
}

for name, clf in classifiers.items():
    print(f"Training {name}...")
    clf.fit(posttrain_features_30, y_train)
    y_pred = clf.predict(posttest_features_30)
    train_accuracy = clf.score(posttrain_features_30, y_train)
    print(f"{name} Train Accuracy: {train_accuracy:.2f}")
    test_accuracy = accuracy_score(y_test, y_pred)
    print("Test Accuracy:", test_accuracy)
    recall = recall_score(y_test, y_pred)
    print("Test Recall:", recall)
    precision = precision_score(y_test, y_pred)
    print("Test Precision:", precision)
    f1Score = f1_score(y_test, y_pred)
    print("Test F1_Score:", f1Score)
    print()
